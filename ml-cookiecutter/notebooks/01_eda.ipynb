# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook provides a template for exploring your dataset.

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Project imports
from ml_project.config import settings
from ml_project.data import load_csv

# Display settings
pd.set_option('display.max_columns', 50)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# Load your dataset
# df = load_csv('raw/your_data.csv')
# df.head()

# %% [markdown]
# ## Data Overview

# %%
# Uncomment when data is loaded
# print(f"Shape: {df.shape}")
# print(f"\nColumn types:\n{df.dtypes}")
# print(f"\nMissing values:\n{df.isnull().sum()}")
# df.describe()

# %% [markdown]
# ## Visualizations

# %%
# Add your visualizations here
# Example:
# fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# df['column'].hist(ax=axes[0])
# df.boxplot(column='column', ax=axes[1])
# plt.tight_layout()
